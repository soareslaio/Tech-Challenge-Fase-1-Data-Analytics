# %% [markdown]
# #TRATANDO DATAFRAME DE PRODUÇÃO DE VINHOS

# %%
#IMPORTANTO BIBLIOTECAS
import pandas as pd

# %%
#CONFIGURANDO A PRECISÃO NUMERICA PARA 2 CASAS DECIMAIS
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
#PARA IMPORTAR FONTE DE DADOS DIRETO DO DRIVE
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#CRIANDO UM DATAFRAME A PARTIR DO ARQUIVO CSV||
df_prod = pd.read_csv('/content/drive/MyDrive/Tech Challenge 1 modulo - FIAP/Dados Brutos/Producao.csv',sep=';',header=None)

# %%
#RENOMEANDO AS COLUNAS
ano = 1970
df_prod.rename(
    columns={0: 'id', 1: 'categoria', 2: 'tipo'}
    | {col: f'quantidade(l)_{ano + (col - 3)}' for col in df_prod.columns[3:]},
    inplace=True
)

# %%
#PADRONIZNADO A NOMENCLATURA DAS LINHAS DAS COLUNAS CATEGORIA E TIPO
df_prod[['categoria','tipo']] = df_prod[['categoria','tipo']].applymap(lambda x: x.lower())

# %%
#ANALISANDO QUANTIDADE DE COLUNAS
df_prod.columns[0:-1]
# Out:
# Index(['id', 'categoria', 'tipo', 'quantidade(l)_1970', 'quantidade(l)_1971',
#        'quantidade(l)_1972', 'quantidade(l)_1973', 'quantidade(l)_1974',
#        'quantidade(l)_1975', 'quantidade(l)_1976', 'quantidade(l)_1977',
#        'quantidade(l)_1978', 'quantidade(l)_1979', 'quantidade(l)_1980',
#        'quantidade(l)_1981', 'quantidade(l)_1982', 'quantidade(l)_1983',
#        'quantidade(l)_1984', 'quantidade(l)_1985', 'quantidade(l)_1986',
#        'quantidade(l)_1987', 'quantidade(l)_1988', 'quantidade(l)_1989',
#        'quantidade(l)_1990', 'quantidade(l)_1991', 'quantidade(l)_1992',
#        'quantidade(l)_1993', 'quantidade(l)_1994', 'quantidade(l)_1995',
#        'quantidade(l)_1996', 'quantidade(l)_1997', 'quantidade(l)_1998',
#        'quantidade(l)_1999', 'quantidade(l)_2000', 'quantidade(l)_2001',
#        'quantidade(l)_2002', 'quantidade(l)_2003', 'quantidade(l)_2004',
#        'quantidade(l)_2005', 'quantidade(l)_2006', 'quantidade(l)_2007',
#        'quantidade(l)_2008', 'quantidade(l)_2009', 'quantidade(l)_2010',
#        'quantidade(l)_2011', 'quantidade(l)_2012', 'quantidade(l)_2013',
#        'quantidade(l)_2014', 'quantidade(l)_2015', 'quantidade(l)_2016',
#        'quantidade(l)_2017', 'quantidade(l)_2018'],
#       dtype='object')

# %%
#ANALISANDO AS INFORMAÇÕES DO DATAFRAME DE PRODUÇÃO PARA TER UM PANORAMA GERAL
df_prod.info()

# %%
#ANALISANDO SE EXISTEM DADOS DUPLICADOS
df_prod[['categoria','tipo']].value_counts()

# %%
#VALIDANDO SE EXISTEM VALORES NULOS
contagem_nulos = df_prod.isnull().sum()
contagem_nulos

# %%
#ANALISANDO SE EXISTEM VALORES DUPLICADOS PARA TIPO
df_prod['tipo'].value_counts()

# %%
#ANALISANDO SE EXISTEM VALORES DUPLICADOS PARA CATEGORIAS
df_prod['categoria'].value_counts()
# Out:
# vinho de mesa                    4
# vinho fino mesa                  4
# derivados                        3
# de_pisco                         1
# de_brandy                        1
# de_néctar de uva                 1
# de_licorosos                     1
# de_compostos                     1
# de_jeropiga                      1
# de_filtrado                      1
# de_frisante                      1
# de_destilado                     1
# de_vinho composto                1
# de_mistelas                      1
# de_licor de bagaceira            1
# de_vinagre                       1
# de_borra líquida                 1
# de_borra seca                    1
# de_bagaceira                     1
# de_mosto de uva com bagaço       1
# de_mosto dessulfitado            1
# de_espumante moscatel            1
# suco                             1
# su_suco de uva simples           1
# su_suco concentrado              1
# su_suco de uva adoçado           1
# su_suco de uva reconstituído     1
# de_espumante                     1
# de_base espumante                1
# de_mosto concentrado             1
# de_base espumante moscatel       1
# de_base champenoise champanha    1
# de_base charmat champanha        1
# de_bebida de uva                 1
# de_polpa de uva                  1
# de_mosto simples                 1
# de_outros derivados              1
# Name: categoria, dtype: int64

# %%
#DECLARANDO LISTA COM OS TIPOS DE VINHOS
tipos_vinhos = ['tinto','branco','rosado','vinho leve','vinho licoroso']

# %%
#CRIANDO NOVA VARIAVEL PARA ARMAZENAR SOMENTE OS TIPOS DE VINHOS DESEJADOS
df_prod_vinhos = df_prod[df_prod['tipo'].isin(tipos_vinhos)]

# %%
#ANALISANDO ESTATISTICA DESCRITIVA
df_prod_vinhos.describe()
# Out:
#          id  quantidade(l)_1970  quantidade(l)_1971  quantidade(l)_1972  \
# count  8.00                8.00                8.00                8.00
# mean  12.38         30138493.75         22231339.12         21004008.50
# std   13.80         59966934.48         41475025.48         40339871.38
# min    2.00                0.00                0.00                0.00
# 25%    3.75           558675.00           498515.25           754972.50
# 50%    6.50          4169978.50          4213083.00          4297602.00
# 75%   14.50         22231204.75         19734477.25         16706979.00
# max   35.00        174224052.00        121133369.00        118180926.00
#
#        quantidade(l)_1973  quantidade(l)_1974  quantidade(l)_1975  \
# count                8.00                8.00                8.00
# mean          16134844.38         28189933.62         27103224.88
# std           30748232.60         49952722.44         48770760.28
# min                  0.00                0.00                0.00
# 25%             182925.00          2001746.25          1081130.25
# 50%            2219170.00          7093213.00          8745447.50
# 75%           12916909.00         24993626.50         24371663.25
# max           88589019.00        146544484.00        144274134.00
#
#        quantidade(l)_1976  quantidade(l)_1977  quantidade(l)_1978  ...  \
# count                8.00                8.00                8.00  ...
# mean          22383253.50         29578093.62         29600575.25  ...
# std           39911522.33         52038368.37         54953262.81  ...
# min                  0.00                0.00                0.00  ...
# 25%            1403604.75          3542986.50          3082635.75  ...
# 50%            7312965.50         10543072.50         10040209.50  ...
# 75%           20989443.00         24207814.50         21244200.25  ...
# max          118360170.00        154801826.00        162917363.00  ...
#
#        quantidade(l)_2010  quantidade(l)_2011  quantidade(l)_2012  \
# count                8.00                8.00                8.00
# mean          27511086.62         38179902.50         32247220.88
# std           53778797.20         71418605.99         59571742.58
# min                  0.00                0.00                0.00
# 25%             297210.00           565728.75           394427.25
# 50%            6985607.50         12229656.50         11305297.00
# 75%           18611791.00         29580431.00         26755254.00
# max          157290088.00        210113358.00        175875432.00
#
#        quantidade(l)_2013  quantidade(l)_2014  quantidade(l)_2015  \
# count                8.00                8.00                8.00
# mean          30335856.50         29334179.62         30939192.75
# std           55150710.18         53601363.66         57826751.50
# min                  0.00                0.00                0.00
# 25%             539817.25           728018.25           644840.00
# 50%           11816185.50          9204755.00          8842867.00
# 75%           25383944.25         24400620.25         24560787.00
# max          163111797.00        157776363.00        169811472.00
#
#        quantidade(l)_2016  quantidade(l)_2017  quantidade(l)_2018  \
# count                8.00                8.00                8.00
# mean          13051730.12         37457984.62         32151894.88
# std           25557971.68         74009871.44         64067855.30
# min                  0.00                0.00             8000.00
# 25%             240593.75           903148.50           687718.75
# 50%            4647889.50         11404084.50          9794483.00
# 75%            9262910.00         25476611.25         21646183.00
# max           75279191.00        217527985.00        188270142.00
#
#        quantidade(l)_2019
# count                8.00
# mean          22793080.50
# std           40745022.34
# min                  0.00
# 25%            1188716.75
# 50%            9711183.50
# 75%           19152998.25
# max          121045115.00
#
# [8 rows x 51 columns]

# %%
#TRATANDO VALORES DA COLUNA DE CATEGORIA
mapeando = {0:'vinho de mesa','vm_tinto':'vinho de mesa','vm_branco':'vinho de mesa','vm_rosado':'vinho de mesa',
            'vinho fino de mesa (vinífera)':'vinho fino mesa','vv_tinto':'vinho fino mesa','vv_branco':'vinho fino mesa','vv_rosado':'vinho fino mesa'
            ,'de_vinho leve':'derivados','de_vinho licoroso':'derivados'}
df_prod_vinhos['categoria'] = df_prod_vinhos['categoria'].map(mapeando).fillna(df_prod_vinhos['categoria'])
# Out:
# <ipython-input-93-f588e33e74f8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prod_vinhos['categoria'] = df_prod_vinhos['categoria'].map(mapeando).fillna(df_prod_vinhos['categoria'])

# %%
#TRATANDO VALORES DA COLUNA DE id
mapeando_id = {'vinho de mesa':0,'vinho fino mesa':1,'derivados':2}
df_prod_vinhos['id'] = df_prod_vinhos['categoria'].map(mapeando_id).fillna(df_prod_vinhos['id'])
# Out:
# <ipython-input-94-fae6bfb39eee>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prod_vinhos['id'] = df_prod_vinhos['categoria'].map(mapeando_id).fillna(df_prod_vinhos['id'])

# %%
#MUDANDO O dtype da coluna de id
df_prod_vinhos['id'] = df_prod_vinhos['id'].astype(int)
# Out:
# <ipython-input-95-d54384d71cbd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_prod_vinhos['id'] = df_prod_vinhos['id'].astype(int)

# %%
df_prod_vinhos.head(10)
# Out:
#     id        categoria            tipo  quantidade(l)_1970  \
# 1    0    vinho de mesa           tinto           174224052
# 2    0    vinho de mesa          branco              748400
# 3    0    vinho de mesa          rosado            42236152
# 5    1  vinho fino mesa           tinto             7591557
# 6    1  vinho fino mesa          branco            15562889
# 7    1  vinho fino mesa          rosado              744900
# 33   2        derivados      vinho leve                   0
# 34   2        derivados  vinho licoroso                   0
#
#     quantidade(l)_1971  quantidade(l)_1972  quantidade(l)_1973  \
# 1            121133369           118180926            88589019
# 2              1160500             1812367              243900
# 3             31970782            26960004            27877426
# 5              7265666             6782837             3419625
# 6             15655709            13289304             7930070
# 7               664687             1006630             1018715
# 33                   0                   0                   0
# 34                   0                   0                   0
#
#     quantidade(l)_1974  quantidade(l)_1975  quantidade(l)_1976  ...  \
# 1            146544484           144274134           118360170  ...
# 2              4138768             1441507             1871473  ...
# 3             43192093            31685568            24333795  ...
# 5             10047658            14731106            12405154  ...
# 6             18927471            21933695            19874659  ...
# 7              2668995             2759789             2220777  ...
# 33                   0                   0                   0  ...
# 34                   0                   0                   0  ...
#
#     quantidade(l)_2010  quantidade(l)_2011  quantidade(l)_2012  \
# 1            157290088           210113358           175875432
# 2             35408083            46007504            34938249
# 3              2569809             1719887             1963356
# 5             11401406            24104740            24027589
# 6             13013027            22739426            20647238
# 7               391280              754305              525903
# 33                   0                   0                   0
# 34               15000                   0                   0
#
#     quantidade(l)_2013  quantidade(l)_2014  quantidade(l)_2015  \
# 1            163111797           157776363           169811472
# 2             32066403            37438069            39557250
# 3              1726022              958691              939838
# 5             23156458            17208996            16745896
# 6             21906349            20054804            19561966
# 7               719723             1200514              841120
# 33                   0                   0                   0
# 34                 100               36000               56000
#
#     quantidade(l)_2016  quantidade(l)_2017  quantidade(l)_2018  \
# 1             75279191             1365957           188270142
# 2             10727099           217527985            29229970
# 3               312725            36121245              875524
# 5              8774847            21442212            19118254
# 6              8705066            21928400            18297257
# 7               590713             1167258             1291709
# 33                   0                   0                8000
# 34               24200              110820              124303
#
#     quantidade(l)_2019
# 1            121045115
# 2             22032828
# 3              1551794
# 5             17389377
# 6             18193055
# 7              2032990
# 33                   0
# 34               99485
#
# [8 rows x 53 columns]

# %%
#ANALISANDO INFORMAÇÕES DO NOVO DF
df_prod_vinhos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 1 to 34
# Data columns (total 53 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  8 non-null      int64
#  1   categoria           8 non-null      object
#  2   tipo                8 non-null      object
#  3   quantidade(l)_1970  8 non-null      int64
#  4   quantidade(l)_1971  8 non-null      int64
#  5   quantidade(l)_1972  8 non-null      int64
#  6   quantidade(l)_1973  8 non-null      int64
#  7   quantidade(l)_1974  8 non-null      int64
#  8   quantidade(l)_1975  8 non-null      int64
#  9   quantidade(l)_1976  8 non-null      int64
#  10  quantidade(l)_1977  8 non-null      int64
#  11  quantidade(l)_1978  8 non-null      int64
#  12  quantidade(l)_1979  8 non-null      int64
#  13  quantidade(l)_1980  8 non-null      int64
#  14  quantidade(l)_1981  8 non-null      int64
#  15  quantidade(l)_1982  8 non-null      int64
#  16  quantidade(l)_1983  8 non-null      int64
#  17  quantidade(l)_1984  8 non-null      int64
#  18  quantidade(l)_1985  8 non-null      int64
#  19  quantidade(l)_1986  8 non-null      int64
#  20  quantidade(l)_1987  8 non-null      int64
#  21  quantidade(l)_1988  8 non-null      int64
#  22  quantidade(l)_1989  8 non-null      int64
#  23  quantidade(l)_1990  8 non-null      int64
#  24  quantidade(l)_1991  8 non-null      int64
#  25  quantidade(l)_1992  8 non-null      int64
#  26  quantidade(l)_1993  8 non-null      int64
#  27  quantidade(l)_1994  8 non-null      int64
#  28  quantidade(l)_1995  8 non-null      int64
#  29  quantidade(l)_1996  8 non-null      int64
#  30  quantidade(l)_1997  8 non-null      int64
#  31  quantidade(l)_1998  8 non-null      int64
#  32  quantidade(l)_1999  8 non-null      int64
#  33  quantidade(l)_2000  8 non-null      int64
#  34  quantidade(l)_2001  8 non-null      int64
#  35  quantidade(l)_2002  8 non-null      int64
#  36  quantidade(l)_2003  8 non-null      int64
#  37  quantidade(l)_2004  8 non-null      int64
#  38  quantidade(l)_2005  8 non-null      int64
#  39  quantidade(l)_2006  8 non-null      int64
#  40  quantidade(l)_2007  8 non-null      int64
#  41  quantidade(l)_2008  8 non-null      int64
#  42  quantidade(l)_2009  8 non-null      int64
#  43  quantidade(l)_2010  8 non-null      int64
#  44  quantidade(l)_2011  8 non-null      int64
#  45  quantidade(l)_2012  8 non-null      int64
#  46  quantidade(l)_2013  8 non-null      int64
#  47  quantidade(l)_2014  8 non-null      int64
#  48  quantidade(l)_2015  8 non-null      int64
#  49  quantidade(l)_2016  8 non-null      int64
#  50  quantidade(l)_2017  8 non-null      int64
#  51  quantidade(l)_2018  8 non-null      int64
#  52  quantidade(l)_2019  8 non-null      int64
# dtypes: int64(51), object(2)
# memory usage: 3.4+ KB

# %%
#EXPORTANDO DF TRATADO PARA SEGUIR COM ANALISE
df_prod_vinhos.to_csv('Producao.csv',index=False)
